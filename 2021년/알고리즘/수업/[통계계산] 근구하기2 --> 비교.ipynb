# %%
import time
import pandas as pd
import math

def equation(x):
    return x - math.exp(-x) -2
error = 1e-7

df = pd.DataFrame()
columns = ["Method", "Time", "iteration"]

# %%
def equation(x):
    return x**2006 + 2006*x +1
error = 1e-5

# %% [markdown]
# # binary

# %%
# 1) bisection method
# continuous 해야함
# 한번에 하나밖에 못찾는 다는 단점이 있음.

def binary(left,right,cnt):
    mid = (left + right)/2
    value = equation(mid)
    if abs(value) < error:
        print("x = {}, f(x) = {}, cnt = {}".format(mid,value,cnt))
        return cnt
    if equation(left) * value < 0:
        return binary(left,mid,cnt+1)
    if value * equation(right) < 0:
        return binary(mid,right,cnt+1)
        

start = time.time()
iteration  = binary(-1,1,0)
end = time.time()
print("time = {}".format(end - start))
# Out:
# x = -0.0004985034465789795, f(x) = 2.086162567138672e-06, cnt = 25
# time = 0.0003478527069091797

# %%
temp = [("bisection",end-start,iteration)]
df = pd.DataFrame(temp)

# %%
df
# Out:
#            0         1   2
# 0  bisection  0.000348  25

# %% [markdown]
# # Secant Method

# %%
def secant(left,right,cnt):
    mid = right - equation(right)*(right - left)/(equation(right) - equation(left))
    if abs(equation(mid)) < error:
        print("x = {}, f(x) = {}, cnt = {}".format(mid, equation(mid),cnt))
        return cnt
    else:
        return secant(right,mid,cnt+1) #조심하기 x0 --> x1 --> x2 순이기 때문에 right가 왼쪽으로 옴.

left, right = -1,1
start = time.time()
iteration = secant(left,right,0)
end = time.time()
# Out:
# x = -0.0004985044865403788, f(x) = 1.1102230246251565e-16, cnt = 2

# %%
temp = [("secant",end-start,iteration)]
temp = pd.DataFrame(temp)
df = pd.concat([df,temp])
df
# Out:
#            0         1   2
# 0  bisection  0.000348  25
# 0     secant  0.000223   2

# %% [markdown]
# # False

# %%
def solve(left,right,cnt):
    mid = right - equation(right)*(left - right)/(equation(left) - equation(right))
    if abs(equation(mid)) < error:
        print("x = {}, f(x) = {}, cnt = {}".format(mid, equation(mid),cnt))
        return cnt
    
    # left(X0)와 mid(X2)의 함숫값을 곱한 부호가 다르면 right을 가운데로 옮겨준다.
    if equation(mid) * equation(left) < 0:
        right = mid
    # left
    else:
        left = mid 
    return solve(left,right,cnt+1)
    
left, right = -5,5
start = time.time()
iteration = solve(left,right,0)
end = time.time()
# Out:
# x = 2.1200283265717963, f(x) = 9.80967262975696e-08, cnt = 323

# %%
temp = [("False",end-start,iteration)]
temp = pd.DataFrame(temp)
df = pd.concat([df,temp])
df
# Out:
#         0         1    2
# 0  binary  0.001155   25
# 0  secant  0.003524    4
# 0   False  0.001957  323

# %% [markdown]
# # newton

# %%
fprime
# Out:
# 2006*x**2005 + 2006

# %%
import sympy
from sympy import symbols, Derivative

#기호화
x = symbols('x')
#fx = x - sympy.exp(-x) -2
fx = x**2006 + 2006*x +1
fprime = Derivative(fx,x).doit()

def solve(now, cnt):
    new = float(now) - float(fx.subs({x:now}))/float(fprime.subs({x:now}))
    result = fx.subs({x:new})
    # f(x+1)이 error에 가깝다면.
    if abs(result) < error:
        print("x = {}, f(x) = {}, cnt = {}".format(new, result ,cnt))
        return cnt
    else:
        return solve(new,cnt+1)


start = time.time()
iteration = solve(1,0)
end = time.time()
# Out:
# x = -0.0004985044865403743, f(x) = 9.21485110438880E-15, cnt = 1

# %%
temp = [("Newton",end-start,iteration)]
temp = pd.DataFrame(temp)
df = pd.concat([df,temp])
df
# Out:
#            0         1   2
# 0  bisection  0.000348  25
# 0     secant  0.000223   2
# 0     Newton  0.000879   1

# %% [markdown]
# # Fixed point

# %%
def fixed_point(point,cnt):
    print(point)
    #함숫값
    value = float(fx.subs(x,point))
    if abs(value) < error:
        print("x = {}, f(x) = {}, cnt = {}".format(point, value ,cnt))
        return cnt
    else:
        return fixed_point(value,cnt+1)
    
start = time.time()
iteration = fixed_point(0.1,0)
end = time.time()
# Out:
# 0.1
# 201.60000000000002
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# inf
# ERROR:root:Internal Python error in the inspect module.
# Below is the traceback from this internal error.
# Traceback (most recent call last):
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 3343, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-34-0d5a31f963dd>", line 12, in <module>
#     iteration = fixed_point(0.1,0)
#   File "<ipython-input-34-0d5a31f963dd>", line 9, in fixed_point
#     return fixed_point(value,cnt+1)
#   File "<ipython-input-34-0d5a31f963dd>", line 9, in fixed_point
#     return fixed_point(value,cnt+1)
#   File "<ipython-input-34-0d5a31f963dd>", line 9, in fixed_point
#     return fixed_point(value,cnt+1)
#   [Previous line repeated 2950 more times]
#   File "<ipython-input-34-0d5a31f963dd>", line 4, in fixed_point
#     value = float(fx.subs(x,point))
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 939, in subs
#     sequence[i] = None if _aresame(*s) else tuple(s)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 1907, in _aresame
#     if i != j or type(i) != type(j):
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/basic.py", line 366, in __ne__
#     return not self == other
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/expr.py", line 126, in __eq__
#     other = _sympify(other)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py", line 439, in _sympify
#     return sympify(a, strict=True)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/sympy/core/sympify.py", line 277, in sympify
#     is_sympy = getattr(a, '__sympy__', None)
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py", line 2044, in showtraceback
#     stb = value._render_traceback_()
# AttributeError: 'RecursionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 1169, in get_records
#     return _fixed_getinnerframes(etb, number_of_lines_of_context, tb_offset)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 316, in wrapped
#     return f(*args, **kwargs)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 350, in _fixed_getinnerframes
#     records = fix_frame_records_filenames(inspect.getinnerframes(etb, context))
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/inspect.py", line 1503, in getinnerframes
#     frameinfo = (tb.tb_frame,) + getframeinfo(tb, context)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/inspect.py", line 1465, in getframeinfo
#     lines, lnum = findsource(frame)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py", line 170, in findsource
#     file = getsourcefile(object) or getfile(object)
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/inspect.py", line 708, in getsourcefile
#     if getattr(getmodule(object, filename), '__loader__', None) is not None:
#   File "/Users/igyuseog/opt/anaconda3/lib/python3.8/inspect.py", line 745, in getmodule
#     if ismodule(module) and hasattr(module, '__file__'):
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# RecursionError                            Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# <ipython-input-34-0d5a31f963dd> in <module>
#      11 start = time.time()
# ---> 12 iteration = fixed_point(0.1,0)
#      13 end = time.time()
#
# <ipython-input-34-0d5a31f963dd> in fixed_point(point, cnt)
#       8     else:
# ----> 9         return fixed_point(value,cnt+1)
#      10
#
# ... last 1 frames repeated, from the frame below ...
#
# <ipython-input-34-0d5a31f963dd> in fixed_point(point, cnt)
#       8     else:
# ----> 9         return fixed_point(value,cnt+1)
#      10
#
# RecursionError: maximum recursion depth exceeded
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2043                         # in the engines. This should return a list of strings.
# -> 2044                         stb = value._render_traceback_()
#    2045                     except Exception:
#
# AttributeError: 'RecursionError' object has no attribute '_render_traceback_'
#
# During handling of the above exception, another exception occurred:
#
# TypeError                                 Traceback (most recent call last)
#     [... skipping hidden 1 frame]
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/interactiveshell.py in showtraceback(self, exc_tuple, filename, tb_offset, exception_only, running_compiled_code)
#    2044                         stb = value._render_traceback_()
#    2045                     except Exception:
# -> 2046                         stb = self.InteractiveTB.structured_traceback(etype,
#    2047                                             value, tb, tb_offset=tb_offset)
#    2048
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1433         else:
#    1434             self.tb = tb
# -> 1435         return FormattedTB.structured_traceback(
#    1436             self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1437
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, value, tb, tb_offset, number_of_lines_of_context)
#    1333         if mode in self.verbose_modes:
#    1334             # Verbose modes need a full traceback
# -> 1335             return VerboseTB.structured_traceback(
#    1336                 self, etype, value, tb, tb_offset, number_of_lines_of_context
#    1337             )
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in structured_traceback(self, etype, evalue, etb, tb_offset, number_of_lines_of_context)
#    1190         """Return a nice text document describing the traceback."""
#    1191
# -> 1192         formatted_exception = self.format_exception_as_a_whole(etype, evalue, etb, number_of_lines_of_context,
#    1193                                                                tb_offset)
#    1194
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in format_exception_as_a_whole(self, etype, evalue, etb, number_of_lines_of_context, tb_offset)
#    1148
#    1149
# -> 1150         last_unique, recursion_repeat = find_recursion(orig_etype, evalue, records)
#    1151
#    1152         frames = self.format_records(records, last_unique, recursion_repeat)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in find_recursion(etype, value, records)
#     448     # quarter of the traceback (250 frames by default) is repeats, and find the
#     449     # first frame (from in to out) that looks different.
# --> 450     if not is_recursion_error(etype, value, records):
#     451         return len(records), 0
#     452
#
# ~/opt/anaconda3/lib/python3.8/site-packages/IPython/core/ultratb.py in is_recursion_error(etype, value, records)
#     435     return (etype is recursion_error_type) \
#     436            and "recursion" in str(value).lower() \
# --> 437            and len(records) > _FRAME_RECURSION_LIMIT
#     438
#     439 def find_recursion(etype, value, records):
#
# TypeError: object of type 'NoneType' has no len()

# %%
df.columns = columns

# %% [markdown]
# # 결론: 비교
#
# - binary가 제일 빠른 것으로 나온다.
# - iteration에서는 secant method가 제일 적었고
# - iteration이 제일 많은 false method의 경우 2번째로 빠른 시간을 보여주었다.
# - fixed method의 경우, Inf가 나와서 해당 식에서 풀이가 불가한 것으로 보여진다.

# %%
df.columns = columns
df
# Out:
#       Method      Time  iteration
# 0  bisection  0.000348         25
# 0     secant  0.000223          2
# 0     Newton  0.000879          1
