# %%
1+2+3
# Out:
# 6

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

x= np.arange(0,6,0.1)
plt.plot(x, np.cos(x))
plt.show()

# %% [markdown]
# # 이것은 마크다운 셀입니다. 코드셀이 아니죠
# ## 좀 더 작은 제목입니다.
# ### 더 작은 제목입니다.
# __강조하는 단어 혹은 문장은__ 이것입니다.
# _하나의 언더_를 붙이면

# %%
y = np.sin(x)
plt.plot(x,y)
plt.show()
