# %% [markdown]
# - Unsupervised Machine Learing
#
# 비지도학습으로, 차원축소와 같은 것들을 수행가능 --> 대표적으로 PCA가 있다
#
#
#
#
# - Cross Validation(교차검증)
#
# 1)Holdout Cross Validation
# ![image.png](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2Fb0zJMh%2FbtqEmKZ0EVm%2FqZoERRPcsFygw5kx9UsTek%2Fimg.png)

# %% [markdown]
# 2) K-Fold Validation
#
# 데이터를 K개로 나눠서, K번의 반복을 통해서 나온 결과값을 평균내어 검증 결과값으로 사용한다. 가장 효과적인 parmeter를 찾는 등, 모델튜닝을 위해서 사용된다.
#
# ![image.png](https://img1.daumcdn.net/thumb/R1280x0/?scode=mtistory2&fname=https%3A%2F%2Fblog.kakaocdn.net%2Fdn%2FdPJrQJ%2FbtqEni9OmAX%2Fz5OXiHhZAAMzrIvWEEOuJK%2Fimg.png)

# %% [markdown]
# # 1.1.3 Decision Tree

# %%
from sklearn import tree

X = [[0,0], [1,1]]
Y = [0,1]

clf = tree.DecisionTreeClassifier()
clf.fit(X,Y)
# Out:
# DecisionTreeClassifier()

# %%
# 어떤 값을 예측
predict_value = clf.predict([[1,1]])

# 확률을 예측 해준다.
prob = clf.predict_proba([[0.5,0.5]])
prob
# Out:
# array([[1., 0.]])

# %%
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris
from sklearn import tree
X, y = load_iris(return_X_y = True)

model = tree.DecisionTreeClassifier().fit(X,y)

plt.figure(figsize = (20,10))
tree.plot_tree(model, filled = True)
# Out:
# [Text(558.0, 498.3, 'X[2] <= 2.45\ngini = 0.667\nsamples = 150\nvalue = [50, 50, 50]'),
#  Text(472.15384615384613, 407.70000000000005, 'gini = 0.0\nsamples = 50\nvalue = [50, 0, 0]'),
#  Text(643.8461538461538, 407.70000000000005, 'X[3] <= 1.75\ngini = 0.5\nsamples = 100\nvalue = [0, 50, 50]'),
#  Text(343.38461538461536, 317.1, 'X[2] <= 4.95\ngini = 0.168\nsamples = 54\nvalue = [0, 49, 5]'),
#  Text(171.69230769230768, 226.5, 'X[3] <= 1.65\ngini = 0.041\nsamples = 48\nvalue = [0, 47, 1]'),
#  Text(85.84615384615384, 135.89999999999998, 'gini = 0.0\nsamples = 47\nvalue = [0, 47, 0]'),
#  Text(257.53846153846155, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(515.0769230769231, 226.5, 'X[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(429.23076923076917, 135.89999999999998, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(600.9230769230769, 135.89999999999998, 'X[2] <= 5.45\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(515.0769230769231, 45.299999999999955, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(686.7692307692307, 45.299999999999955, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
#  Text(944.3076923076923, 317.1, 'X[2] <= 4.85\ngini = 0.043\nsamples = 46\nvalue = [0, 1, 45]'),
#  Text(858.4615384615383, 226.5, 'X[1] <= 3.1\ngini = 0.444\nsamples = 3\nvalue = [0, 1, 2]'),
#  Text(772.6153846153845, 135.89999999999998, 'gini = 0.0\nsamples = 2\nvalue = [0, 0, 2]'),
#  Text(944.3076923076923, 135.89999999999998, 'gini = 0.0\nsamples = 1\nvalue = [0, 1, 0]'),
#  Text(1030.1538461538462, 226.5, 'gini = 0.0\nsamples = 43\nvalue = [0, 0, 43]')]

# %% [markdown]
# # 당뇨병 예측 모델 만들기

# %%
from sklearn import tree
from sklearn.model_selection import train_test_split

import pandas as pd
import seaborn as sns

df = pd.read_csv("diabetes.csv")

# %%
# train/test 데이터 나누기
X,y = df.iloc[:,:-1], df.iloc[:,-1]
X_train, X_test, y_train, y_test = train_test_split(X,y, train_size= 0.7, random_state = 42)

# %%
# 학습 및 평가하기
model = tree.DecisionTreeClassifier().fit(X_train,y_train)
acc = model.score(X_test,y_test)
print("acc = ", acc*100)
# Out:
# acc =  70.12987012987013

# %%
# 시각화하기
import matplotlib.pyplot as plt

plt.figure(figsize = (20,20))
feature_names = df.columns[:-1].tolist()
tree.plot_tree(model, feature_names= feature_names, filled = True, fontsize= 10)
# Out:
# [Text(666.8963068181819, 1050.96, 'Glucose <= 154.5\ngini = 0.455\nsamples = 537\nvalue = [349, 188]'),
#  Text(316.4289772727273, 978.48, 'Age <= 28.5\ngini = 0.383\nsamples = 454\nvalue = [337, 117]'),
#  Text(163.45454545454547, 906.0, 'Glucose <= 127.5\ngini = 0.22\nsamples = 238\nvalue = [208, 30]'),
#  Text(90.18181818181819, 833.52, 'BMI <= 49.1\ngini = 0.117\nsamples = 192\nvalue = [180, 12]'),
#  Text(78.9090909090909, 761.04, 'BMI <= 31.4\ngini = 0.1\nsamples = 190\nvalue = [180, 10]'),
#  Text(22.545454545454547, 688.56, 'DiabetesPedigreeFunction <= 0.672\ngini = 0.018\nsamples = 111\nvalue = [110, 1]'),
#  Text(11.272727272727273, 616.08, 'gini = 0.0\nsamples = 96\nvalue = [96, 0]'),
#  Text(33.81818181818182, 616.08, 'DiabetesPedigreeFunction <= 0.697\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(22.545454545454547, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(45.09090909090909, 543.6, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(135.27272727272728, 688.56, 'Insulin <= 9.0\ngini = 0.202\nsamples = 79\nvalue = [70, 9]'),
#  Text(90.18181818181819, 616.08, 'Glucose <= 111.5\ngini = 0.384\nsamples = 27\nvalue = [20, 7]'),
#  Text(67.63636363636364, 543.6, 'SkinThickness <= 40.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(56.36363636363637, 471.12, 'gini = 0.0\nsamples = 17\nvalue = [17, 0]'),
#  Text(78.9090909090909, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(112.72727272727273, 543.6, 'BloodPressure <= 72.0\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(101.45454545454547, 471.12, 'BloodPressure <= 65.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(90.18181818181819, 398.64, 'BMI <= 32.6\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(78.9090909090909, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(101.45454545454547, 326.15999999999997, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(112.72727272727273, 398.64, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(124.0, 471.12, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(180.36363636363637, 616.08, 'Pregnancies <= 4.5\ngini = 0.074\nsamples = 52\nvalue = [50, 2]'),
#  Text(157.8181818181818, 543.6, 'DiabetesPedigreeFunction <= 0.64\ngini = 0.04\nsamples = 49\nvalue = [48, 1]'),
#  Text(146.54545454545456, 471.12, 'gini = 0.0\nsamples = 43\nvalue = [43, 0]'),
#  Text(169.0909090909091, 471.12, 'DiabetesPedigreeFunction <= 0.676\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(157.8181818181818, 398.64, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(180.36363636363637, 398.64, 'gini = 0.0\nsamples = 5\nvalue = [5, 0]'),
#  Text(202.90909090909093, 543.6, 'Age <= 26.5\ngini = 0.444\nsamples = 3\nvalue = [2, 1]'),
#  Text(191.63636363636365, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(214.1818181818182, 471.12, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(101.45454545454547, 761.04, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(236.72727272727275, 833.52, 'BloodPressure <= 56.0\ngini = 0.476\nsamples = 46\nvalue = [28, 18]'),
#  Text(225.45454545454547, 761.04, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(248.0, 761.04, 'BMI <= 30.3\ngini = 0.433\nsamples = 41\nvalue = [28, 13]'),
#  Text(225.45454545454547, 688.56, 'Age <= 27.5\ngini = 0.124\nsamples = 15\nvalue = [14, 1]'),
#  Text(214.1818181818182, 616.08, 'gini = 0.0\nsamples = 13\nvalue = [13, 0]'),
#  Text(236.72727272727275, 616.08, 'Glucose <= 138.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(225.45454545454547, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(248.0, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(270.54545454545456, 688.56, 'BMI <= 32.0\ngini = 0.497\nsamples = 26\nvalue = [14, 12]'),
#  Text(259.2727272727273, 616.08, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(281.8181818181818, 616.08, 'BloodPressure <= 85.0\ngini = 0.463\nsamples = 22\nvalue = [14, 8]'),
#  Text(270.54545454545456, 543.6, 'Pregnancies <= 0.5\ngini = 0.388\nsamples = 19\nvalue = [14, 5]'),
#  Text(248.0, 471.12, 'BMI <= 33.75\ngini = 0.49\nsamples = 7\nvalue = [3, 4]'),
#  Text(236.72727272727275, 398.64, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(259.2727272727273, 398.64, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(293.0909090909091, 471.12, 'BMI <= 32.45\ngini = 0.153\nsamples = 12\nvalue = [11, 1]'),
#  Text(281.8181818181818, 398.64, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(304.3636363636364, 398.64, 'gini = 0.0\nsamples = 11\nvalue = [11, 0]'),
#  Text(293.0909090909091, 543.6, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(469.4034090909091, 906.0, 'BMI <= 26.95\ngini = 0.481\nsamples = 216\nvalue = [129, 87]'),
#  Text(338.1818181818182, 833.52, 'Age <= 29.5\ngini = 0.13\nsamples = 43\nvalue = [40, 3]'),
#  Text(326.90909090909093, 761.04, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(349.4545454545455, 761.04, 'BloodPressure <= 94.0\ngini = 0.091\nsamples = 42\nvalue = [40, 2]'),
#  Text(326.90909090909093, 688.56, 'Glucose <= 133.0\ngini = 0.049\nsamples = 40\nvalue = [39, 1]'),
#  Text(315.6363636363636, 616.08, 'gini = 0.0\nsamples = 34\nvalue = [34, 0]'),
#  Text(338.1818181818182, 616.08, 'Glucose <= 135.0\ngini = 0.278\nsamples = 6\nvalue = [5, 1]'),
#  Text(326.90909090909093, 543.6, 'SkinThickness <= 16.5\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(315.6363636363636, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(338.1818181818182, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(349.4545454545455, 543.6, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(372.0, 688.56, 'BMI <= 12.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(360.72727272727275, 616.08, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(383.2727272727273, 616.08, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(600.625, 833.52, 'Glucose <= 94.5\ngini = 0.5\nsamples = 173\nvalue = [89, 84]'),
#  Text(405.81818181818187, 761.04, 'Glucose <= 28.5\ngini = 0.26\nsamples = 26\nvalue = [22, 4]'),
#  Text(394.54545454545456, 688.56, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(417.0909090909091, 688.56, 'Pregnancies <= 9.5\ngini = 0.153\nsamples = 24\nvalue = [22, 2]'),
#  Text(405.81818181818187, 616.08, 'gini = 0.0\nsamples = 18\nvalue = [18, 0]'),
#  Text(428.3636363636364, 616.08, 'SkinThickness <= 27.0\ngini = 0.444\nsamples = 6\nvalue = [4, 2]'),
#  Text(417.0909090909091, 543.6, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(439.6363636363637, 543.6, 'Insulin <= 27.0\ngini = 0.444\nsamples = 3\nvalue = [1, 2]'),
#  Text(428.3636363636364, 471.12, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(450.90909090909093, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(795.4318181818182, 761.04, 'DiabetesPedigreeFunction <= 0.528\ngini = 0.496\nsamples = 147\nvalue = [67, 80]'),
#  Text(677.7727272727274, 688.56, 'BloodPressure <= 83.0\ngini = 0.498\nsamples = 99\nvalue = [53, 46]'),
#  Text(577.7272727272727, 616.08, 'SkinThickness <= 26.5\ngini = 0.498\nsamples = 75\nvalue = [35, 40]'),
#  Text(496.0, 543.6, 'BMI <= 28.35\ngini = 0.434\nsamples = 44\nvalue = [14, 30]'),
#  Text(473.4545454545455, 471.12, 'DiabetesPedigreeFunction <= 0.25\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(462.1818181818182, 398.64, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(484.72727272727275, 398.64, 'Glucose <= 126.5\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(473.4545454545455, 326.15999999999997, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(496.0, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(518.5454545454546, 471.12, 'BMI <= 31.15\ngini = 0.375\nsamples = 36\nvalue = [9, 27]'),
#  Text(507.2727272727273, 398.64, 'gini = 0.0\nsamples = 9\nvalue = [0, 9]'),
#  Text(529.8181818181819, 398.64, 'BloodPressure <= 67.0\ngini = 0.444\nsamples = 27\nvalue = [9, 18]'),
#  Text(518.5454545454546, 326.15999999999997, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(541.0909090909091, 326.15999999999997, 'Age <= 36.5\ngini = 0.49\nsamples = 21\nvalue = [9, 12]'),
#  Text(529.8181818181819, 253.67999999999995, 'gini = 0.0\nsamples = 4\nvalue = [4, 0]'),
#  Text(552.3636363636364, 253.67999999999995, 'BloodPressure <= 71.0\ngini = 0.415\nsamples = 17\nvalue = [5, 12]'),
#  Text(541.0909090909091, 181.20000000000005, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(563.6363636363636, 181.20000000000005, 'DiabetesPedigreeFunction <= 0.21\ngini = 0.32\nsamples = 15\nvalue = [3, 12]'),
#  Text(552.3636363636364, 108.72000000000003, 'DiabetesPedigreeFunction <= 0.132\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(541.0909090909091, 36.24000000000001, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(563.6363636363636, 36.24000000000001, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(574.909090909091, 108.72000000000003, 'gini = 0.0\nsamples = 11\nvalue = [0, 11]'),
#  Text(659.4545454545455, 543.6, 'Glucose <= 127.5\ngini = 0.437\nsamples = 31\nvalue = [21, 10]'),
#  Text(620.0, 471.12, 'BloodPressure <= 67.0\ngini = 0.298\nsamples = 22\nvalue = [18, 4]'),
#  Text(597.4545454545455, 398.64, 'DiabetesPedigreeFunction <= 0.394\ngini = 0.5\nsamples = 6\nvalue = [3, 3]'),
#  Text(586.1818181818182, 326.15999999999997, 'BloodPressure <= 45.0\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(574.909090909091, 253.67999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(597.4545454545455, 253.67999999999995, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(608.7272727272727, 326.15999999999997, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(642.5454545454546, 398.64, 'Insulin <= 155.0\ngini = 0.117\nsamples = 16\nvalue = [15, 1]'),
#  Text(631.2727272727273, 326.15999999999997, 'gini = 0.0\nsamples = 14\nvalue = [14, 0]'),
#  Text(653.8181818181819, 326.15999999999997, 'BMI <= 34.8\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(642.5454545454546, 253.67999999999995, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(665.0909090909091, 253.67999999999995, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(698.909090909091, 471.12, 'DiabetesPedigreeFunction <= 0.311\ngini = 0.444\nsamples = 9\nvalue = [3, 6]'),
#  Text(687.6363636363636, 398.64, 'Pregnancies <= 12.0\ngini = 0.375\nsamples = 4\nvalue = [3, 1]'),
#  Text(676.3636363636364, 326.15999999999997, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(698.909090909091, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(710.1818181818182, 398.64, 'gini = 0.0\nsamples = 5\nvalue = [0, 5]'),
#  Text(777.8181818181819, 616.08, 'Insulin <= 124.0\ngini = 0.375\nsamples = 24\nvalue = [18, 6]'),
#  Text(755.2727272727274, 543.6, 'BMI <= 41.2\ngini = 0.188\nsamples = 19\nvalue = [17, 2]'),
#  Text(744.0, 471.12, 'SkinThickness <= 39.5\ngini = 0.105\nsamples = 18\nvalue = [17, 1]'),
#  Text(732.7272727272727, 398.64, 'gini = 0.0\nsamples = 16\nvalue = [16, 0]'),
#  Text(755.2727272727274, 398.64, 'Insulin <= 44.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(744.0, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(766.5454545454546, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(766.5454545454546, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(800.3636363636364, 543.6, 'SkinThickness <= 19.5\ngini = 0.32\nsamples = 5\nvalue = [1, 4]'),
#  Text(789.0909090909091, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(811.6363636363637, 471.12, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(913.0909090909091, 688.56, 'BMI <= 31.6\ngini = 0.413\nsamples = 48\nvalue = [14, 34]'),
#  Text(868.0, 616.08, 'BMI <= 29.1\ngini = 0.498\nsamples = 17\nvalue = [9, 8]'),
#  Text(845.4545454545455, 543.6, 'Glucose <= 132.0\ngini = 0.42\nsamples = 10\nvalue = [3, 7]'),
#  Text(834.1818181818182, 471.12, 'BMI <= 27.35\ngini = 0.219\nsamples = 8\nvalue = [1, 7]'),
#  Text(822.909090909091, 398.64, 'SkinThickness <= 21.0\ngini = 0.5\nsamples = 2\nvalue = [1, 1]'),
#  Text(811.6363636363637, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(834.1818181818182, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(845.4545454545455, 398.64, 'gini = 0.0\nsamples = 6\nvalue = [0, 6]'),
#  Text(856.7272727272727, 471.12, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(890.5454545454546, 543.6, 'BloodPressure <= 86.0\ngini = 0.245\nsamples = 7\nvalue = [6, 1]'),
#  Text(879.2727272727274, 471.12, 'gini = 0.0\nsamples = 6\nvalue = [6, 0]'),
#  Text(901.8181818181819, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [0, 1]'),
#  Text(958.1818181818182, 616.08, 'DiabetesPedigreeFunction <= 1.149\ngini = 0.271\nsamples = 31\nvalue = [5, 26]'),
#  Text(935.6363636363637, 543.6, 'SkinThickness <= 54.5\ngini = 0.142\nsamples = 26\nvalue = [2, 24]'),
#  Text(924.3636363636364, 471.12, 'BloodPressure <= 87.0\ngini = 0.077\nsamples = 25\nvalue = [1, 24]'),
#  Text(913.0909090909091, 398.64, 'gini = 0.0\nsamples = 21\nvalue = [0, 21]'),
#  Text(935.6363636363637, 398.64, 'BMI <= 36.65\ngini = 0.375\nsamples = 4\nvalue = [1, 3]'),
#  Text(924.3636363636364, 326.15999999999997, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(946.909090909091, 326.15999999999997, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(946.909090909091, 471.12, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(980.7272727272727, 543.6, 'Age <= 36.0\ngini = 0.48\nsamples = 5\nvalue = [3, 2]'),
#  Text(969.4545454545455, 471.12, 'gini = 0.0\nsamples = 2\nvalue = [0, 2]'),
#  Text(992.0, 471.12, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1017.3636363636364, 978.48, 'BMI <= 28.7\ngini = 0.247\nsamples = 83\nvalue = [12, 71]'),
#  Text(969.4545454545455, 906.0, 'BMI <= 25.35\ngini = 0.486\nsamples = 12\nvalue = [5, 7]'),
#  Text(958.1818181818182, 833.52, 'gini = 0.0\nsamples = 4\nvalue = [0, 4]'),
#  Text(980.7272727272727, 833.52, 'Age <= 52.5\ngini = 0.469\nsamples = 8\nvalue = [5, 3]'),
#  Text(969.4545454545455, 761.04, 'Pregnancies <= 1.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(958.1818181818182, 688.56, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(980.7272727272727, 688.56, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(992.0, 761.04, 'gini = 0.0\nsamples = 3\nvalue = [3, 0]'),
#  Text(1065.2727272727273, 906.0, 'DiabetesPedigreeFunction <= 1.428\ngini = 0.178\nsamples = 71\nvalue = [7, 64]'),
#  Text(1037.0909090909092, 833.52, 'Glucose <= 165.5\ngini = 0.14\nsamples = 66\nvalue = [5, 61]'),
#  Text(1014.5454545454546, 761.04, 'Glucose <= 164.5\ngini = 0.32\nsamples = 20\nvalue = [4, 16]'),
#  Text(1003.2727272727274, 688.56, 'DiabetesPedigreeFunction <= 0.141\ngini = 0.198\nsamples = 18\nvalue = [2, 16]'),
#  Text(992.0, 616.08, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1014.5454545454546, 616.08, 'Age <= 24.5\ngini = 0.111\nsamples = 17\nvalue = [1, 16]'),
#  Text(1003.2727272727274, 543.6, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1025.818181818182, 543.6, 'gini = 0.0\nsamples = 16\nvalue = [0, 16]'),
#  Text(1025.818181818182, 688.56, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]'),
#  Text(1059.6363636363637, 761.04, 'DiabetesPedigreeFunction <= 0.274\ngini = 0.043\nsamples = 46\nvalue = [1, 45]'),
#  Text(1048.3636363636365, 688.56, 'DiabetesPedigreeFunction <= 0.27\ngini = 0.198\nsamples = 9\nvalue = [1, 8]'),
#  Text(1037.0909090909092, 616.08, 'gini = 0.0\nsamples = 8\nvalue = [0, 8]'),
#  Text(1059.6363636363637, 616.08, 'gini = 0.0\nsamples = 1\nvalue = [1, 0]'),
#  Text(1070.909090909091, 688.56, 'gini = 0.0\nsamples = 37\nvalue = [0, 37]'),
#  Text(1093.4545454545455, 833.52, 'Glucose <= 181.5\ngini = 0.48\nsamples = 5\nvalue = [2, 3]'),
#  Text(1082.1818181818182, 761.04, 'gini = 0.0\nsamples = 3\nvalue = [0, 3]'),
#  Text(1104.7272727272727, 761.04, 'gini = 0.0\nsamples = 2\nvalue = [2, 0]')]

# %%
# featrue의 중요도를 추출해서 시각화하기
sns.barplot(x = model.feature_importances_, y = feature_names)

# %% [markdown]
# # 정리
#
# 1) sklearn에서 제공되는 tree를 통해 의사결정나무 알고리즘을 수행 가능하고, plot_tree를 통해서 시각화도 가능하다.
#
# 2) 학습이 완료된 model을 가지고 feature에 대한 importance를 알 수 있었는데, 이 부분이 상당히 중요한 것 같다.
