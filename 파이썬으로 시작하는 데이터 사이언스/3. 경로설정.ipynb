# %%
# %mv ~ 파일경로 + .  --> 해당 파일을 현재 디렉토리로 넣어준다.
# %mv /C:/Users/LeeKwangWon/Downloads/경상북도_포항시_시내버스노선정보_20190820..csv .
# 현재 디렉토리 내 파일들을 
# %ls
# Out:
# UsageError: Line magic function `%mv` not found.

# %%
#현재 주피터 노트북이 있는 폴더의 경로를 출력합니다.
# %pwd
# Out:
# 'C:\\Users\\LeeKwangWon\\Dropbox\\git\\[부스트코스]파이썬으로 시작하는 데이터 사이언스'

# %%
# 괄호 안에서 shift + tab을 누르면, 도움말을 보실 수 있습니다.
# 엑셀 한글파일은 cp949로 작성되는데, 불러오면서 unicode로 변환되면서 에러가 발생한다. 따라서 인코딩을 바꿔준다.
import pandas as pd
pd.read_csv("Data/경상북도_포항시_시내버스노선정보_20190820..csv", encoding = "cp949")
# Out:
#      노선번호     기점     종점     회차지  승강장개수   노선거리  운행시간  승강장순번  상하행    승강장명칭  \
# 0     101  양덕차고지  양덕차고지  신형주택입구    104  49905   120      0    0    양덕차고지
# 1     101  양덕차고지  양덕차고지  신형주택입구    104  49905   120      1    0  장애인복지회관
# 2     101  양덕차고지  양덕차고지  신형주택입구    104  49905   120      2    0  장량하수처리장
# 3     101  양덕차고지  양덕차고지  신형주택입구    104  49905   120      3    0      포항대
# 4     101  양덕차고지  양덕차고지  신형주택입구    104  49905   120      4    0    삼성쉐르빌
# ...   ...    ...    ...     ...    ...    ...   ...    ...  ...      ...
# 9439  500  문덕차고지  문덕차고지   월포회차지    143      0   180    137    1   문덕마을회관
# 9440  500  문덕차고지  문덕차고지   월포회차지    143      0   180    138    1  오천읍민운동장
# 9441  500  문덕차고지  문덕차고지   월포회차지    143      0   180    139    1  운전면허시험장
# 9442  500  문덕차고지  문덕차고지   월포회차지    143      0   180    140    1     문덕2리
# 9443  500  문덕차고지  문덕차고지   월포회차지    143      0   180    141    1    문덕차고지
#
#        승강장거리     데이터기준일자
# 0       0.00  2019-08-20
# 1     751.30  2019-08-20
# ...
