# %%
#1) 필요한 라이브러리 불러오기.
import csv
import matplotlib.pyplot as plt

#2) 기온 데이터 불러오기
f = open('test.csv')
data = csv.reader(f)
next(data)   # 맨위에 column에 해당하는 이름들을 넘겨준다. 


'''
max_temp = []
for row in data:
    if row[-1] != '':
        max_temp.append(float(row[-1]))

#3) 기온 데이터에서 최고기온을 순서대로 저장하기.
#4) 저장된 데이터를 꺾은선 그래프로 그리기.
plt.plot(max_temp)

#5) 그래프 그리기
plt.show()
'''
# Out:
# "\nmax_temp = []\nfor row in data:\n    if row[-1] != '':\n        max_temp.append(float(row[-1]))\n\n#3) 기온 데이터에서 최고기온을 순서대로 저장하기.\n#4) 저장된 데이터를 꺾은선 그래프로 그리기.\nplt.plot(max_temp)\n\n#5) 그래프 그리기\nplt.show()\n"

# %%
#12월 데이터만 불러오기
key = row[2].split("-")[1]

# %%
max_temp = []
for row in data:
    key = row[2].split("-")[1]
    if key == '12':
        
        max_temp.append(float(row[-1]))

# %%
x = [int(x) for x in range(1903,2021)]
y = max_temp
plt.plot(x,y)
plt.show()

# %% [markdown]
# 1907년부터 2019년까지 12월의 최고기온만 뽑아서 정리해봤다.
# 이걸통해 지구온난화를 이해하고 싶었지만, 아쉽게도 그런 결과를 도출하기는 쉽지 않을 것 같다.
# 일단 문제점 중 한 가지는, x와 y의 shape이 동일해야 (x,y)로 그래프가 그려질 수 있다.
# 그런데, 데이터 손실로 인해 없는 경우가 발생했고, 그
